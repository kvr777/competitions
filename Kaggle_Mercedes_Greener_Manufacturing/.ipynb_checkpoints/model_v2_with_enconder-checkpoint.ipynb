# %% [markdown]
# ## Import data and libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import math as mt
from pylab import savefig

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

# from subprocess import check_output
# print(check_output(["ls", "./input/"]).decode("utf8"))

# preprocessing/decomposition
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler, LabelEncoder
from sklearn.decomposition import PCA

#Import Keras libraries
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, BatchNormalization, Activation
from keras.wrappers.scikit_learn import KerasRegressor
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.layers.recurrent import LSTM
# define custom R2 metrics for Keras backend
from keras import backend as K
# to tune the NN
from keras.constraints import maxnorm
from keras.optimizers import SGD, Adam

# model evaluation
from sklearn.model_selection import cross_val_score, KFold, train_test_split, GridSearchCV
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import r2_score, mean_squared_error

# feature selection
from sklearn.feature_selection import f_regression, mutual_info_regression, VarianceThreshold

# define path to save model
import os
model_path = 'keras_model.h5'

# to make results reproducible
seed = 42

# Read datasets
train = pd.read_csv('./input/train.csv')
test = pd.read_csv('./input/test.csv')

# Remove the outlier
# train=train[train.y<250]

# save IDs for submission
id_test = test['ID'].copy()

# %% [markdown]
# ## Prepare data

# %%
# glue datasets together
total = pd.concat([train, test], axis=0)
print('initial shape: {}'.format(total.shape))

# binary indexes for train/test set split
is_train = ~total.y.isnull()

# find all categorical features
cf = total.select_dtypes(include=['object']).columns

# make one-hot-encoding convenient way - pandas.get_dummies(df) function
dummies = pd.get_dummies(
    total[cf],
    drop_first=False # you can set it = True to ommit multicollinearity (crucial for linear models)
)

print('oh-encoded shape: {}'.format(dummies.shape))

# get rid of old columns and append them encoded
total = pd.concat(
    [
        total.drop(cf, axis=1), # drop old
        dummies # append them one-hot-encoded
    ],
    axis=1 # column-wise
)

print('appended-encoded shape: {}'.format(total.shape))

# recreate train/test again, now with dropped ID column
train, test = total[is_train].drop(['ID'], axis=1), total[~is_train].drop(['ID', 'y'], axis=1)

# drop redundant objects
del total

# check shape
print('\nTrain shape: {}\nTest shape: {}'.format(train.shape, test.shape))
# Out:
# initial shape: (8418, 378)
# oh-encoded shape: (8418, 211)
# appended-encoded shape: (8418, 581)
#
# Train shape: (4209, 580)
# Test shape: (4209, 579)

# %% [markdown]
# ## GENERATE MODEL

# %%
def r2_keras(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true - y_pred )) 
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) ) 
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

def model():
    model = Sequential()
    # Input layer with dimension input_dims and hidden layer i with input_dims neurons. 
    model.add(Dense(input_dims, input_dim=input_dims, activation='relu', kernel_constraint=maxnorm(3)))
    model.add(BatchNormalization())
    model.add(Dropout(0.2))
    model.add(Activation("linear"))
    # Hidden layer
    model.add(Dense(input_dims, activation='relu', kernel_constraint=maxnorm(3)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Activation("linear"))
    # Hidden layer
    model.add(Dense(input_dims, activation='relu', kernel_constraint=maxnorm(3)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Activation("linear"))
    # Hidden layer
    model.add(Dense(input_dims, activation='relu', kernel_constraint=maxnorm(3)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Activation("linear"))
    # Hidden layer
    model.add(Dense(input_dims//2, activation='relu', kernel_constraint=maxnorm(3)))
    model.add(BatchNormalization())
    model.add(Dropout(0.3))
    model.add(Activation("linear"))
    # Output Layer.
    model.add(Dense(1))
    # Use a large learning rate with decay and a large momentum. 
    # Increase your learning rate by a factor of 10 to 100 and use a high momentum value of 0.9 or 0.99
    # sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
    # adam = Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    # compile this model
    model.compile(loss='mean_squared_error', # one may use 'mean_absolute_error' as alternative
                  optimizer='rmsprop',
                  metrics=[r2_keras,"mse"] # you can add several if needed
                 )
    
    # Visualize NN architecture
    print(model.summary())
    return model

def model2():

    model2 = Sequential()
    # Input layer with dimension input_dims and hidden layer i with input_dims neurons. 
    model2.add(Dense(input_dims, 
                    input_dim=input_dims, 
                    activation='relu',
                    kernel_constraint=maxnorm(3)))
    model2.add(BatchNormalization())
    model2.add(Dropout(0.2))
    
#     # Hidden layer1
#     model2.add(Dense(20, init = 'he_normal'))
#     model2.add(Activation('relu'))
#     model2.add(BatchNormalization())    
    
    # Hidden layer2
    model2.add(Dense(4, kernel_initializer='normal'))
    model2.add(Activation('relu'))
    model2.add(Dropout(0.3))
    model2.add(BatchNormalization())    
    
    #output
    model2.add(Dense(1, kernel_initializer='normal'))
    model2.compile(loss = 'mean_squared_error', 
                   optimizer = 'adam',
                   metrics=[r2_keras,"mse"])
    
    # Visualize NN architecture
    print(model2.summary())
    return model2

# %%
# initialize input dimension

input_dims = train.shape[1]-1
# input_dims = train_reduced.shape[1]
    
# make np.seed fixed
np.random.seed(seed)

# initialize estimator, wrap model in KerasRegressor
estimator = KerasRegressor(
    build_fn=model, 
    nb_epoch=300, 
    batch_size=32,
    verbose=1
)

# X, y preparation
X, y = train.drop('y', axis=1).copy().values, train.y.values
X_test = test.values
print('\nTrain shape No Feature Selection: {}\nTest shape No Feature Selection: {}'.format(X.shape, X_test.shape))

"""Return the sample arithmetic mean of data."""
def mean(numbers):
    return float(sum(numbers)) / max(len(numbers), 1)
"""Return sum of square deviations of sequence data."""    
def sum_of_square_deviation(numbers,mean):
    return float(1/len(numbers) * sum((x - mean)** 2 for x in numbers))  

# prepare callbacks
callbacks = [
    EarlyStopping(
        monitor='val_r2_keras', 
        patience=20,
        mode='max',
        verbose=1),
    ModelCheckpoint(
        model_path, 
        monitor='val_r2_keras', 
        save_best_only=True, 
        mode='max',
        verbose=0)
]

# train/validation split
X_tr, X_val, y_tr, y_val = train_test_split(
    X, 
    y, 
    test_size=0.2, 
    random_state=seed
)
# Out:
# Train shape No Feature Selection: (4209, 579)
# Test shape No Feature Selection: (4209, 579)

# %%
# fit estimator
history = estimator.fit(
    X_tr, 
    y_tr, 
    epochs=500,
    validation_data=(X_val, y_val),
    verbose=2,
    callbacks=callbacks,
    shuffle=True
)

# list all data in history
print(history.history.keys())

# summarize history for R^2
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['r2_keras'])
plt.plot(history.history['val_r2_keras'])
plt.title('model accuracy')
plt.ylabel('R^2')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_acc.savefig("model_accuracy.png")

# summarize history for loss
fig_loss = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
fig_loss.savefig("model_loss.png")

# if best iteration's model was saved then load and use it
if os.path.isfile(model_path):
    estimator = load_model(model_path, custom_objects={'r2_keras': r2_keras})

# Plot in blue color the predicted data and in green color the
# actual data to verify visually the accuracy of the model.
predicted = estimator.predict(X_val)
fig_verify = plt.figure(figsize=(100, 50))
plt.plot(predicted, color="blue")
plt.plot(y_val, color="green")
plt.title('prediction')
plt.ylabel('value')
plt.xlabel('row')
plt.legend(['predicted', 'actual data'], loc='upper left')
plt.show()
fig_verify.savefig("model_verify.png")

# check performance on train set
print('MSE train: {}'.format(mean_squared_error(y_tr, estimator.predict(X_tr))**0.5)) # mse train
print('R^2 train: {}'.format(r2_score(y_tr, estimator.predict(X_tr)))) # R^2 train

# check performance on validation set
print('MSE val: {}'.format(mean_squared_error(y_val, estimator.predict(X_val))**0.5)) # mse val
print('R^2 val: {}'.format(r2_score(y_val, estimator.predict(X_val)))) # R^2 val
pass
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 579)               335820
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 579)               2316
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 579)               0
# _________________________________________________________________
# activation_14 (Activation)   (None, 579)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 579)               335820
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 579)               2316
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 579)               0
# _________________________________________________________________
# activation_15 (Activation)   (None, 579)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 579)               335820
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 579)               2316
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 579)               0
# _________________________________________________________________
# activation_16 (Activation)   (None, 579)               0
# _________________________________________________________________
# dense_26 (Dense)             (None, 579)               335820
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 579)               2316
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 579)               0
# _________________________________________________________________
# activation_17 (Activation)   (None, 579)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 289)               167620
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 289)               1156
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 289)               0
# _________________________________________________________________
# activation_18 (Activation)   (None, 289)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 290
# =================================================================
# Total params: 1,521,610.0
# Trainable params: 1,516,400.0
# Non-trainable params: 5,210.0
# _________________________________________________________________
# None
# Train on 3367 samples, validate on 842 samples
# Epoch 1/500
# 10s - loss: 10159.1026 - r2_keras: -6.5499e+01 - mean_squared_error: 10159.1026 - val_loss: 10061.5495 - val_r2_keras: -6.5553e+01 - val_mean_squared_error: 10061.5495
# Epoch 2/500
# 4s - loss: 9943.8411 - r2_keras: -6.4527e+01 - mean_squared_error: 9943.8411 - val_loss: 9908.8754 - val_r2_keras: -6.4545e+01 - val_mean_squared_error: 9908.8754
# Epoch 3/500
# 4s - loss: 9680.1478 - r2_keras: -6.2250e+01 - mean_squared_error: 9680.1478 - val_loss: 9572.9500 - val_r2_keras: -6.2331e+01 - val_mean_squared_error: 9572.9500
# Epoch 4/500
# 4s - loss: 9324.4491 - r2_keras: -6.0754e+01 - mean_squared_error: 9324.4491 - val_loss: 9130.2706 - val_r2_keras: -5.9394e+01 - val_mean_squared_error: 9130.2706
# Epoch 5/500
# 4s - loss: 8888.0987 - r2_keras: -5.7114e+01 - mean_squared_error: 8888.0987 - val_loss: 8477.8681 - val_r2_keras: -5.5074e+01 - val_mean_squared_error: 8477.8681
# Epoch 6/500
# 4s - loss: 8383.2430 - r2_keras: -5.3677e+01 - mean_squared_error: 8383.2430 - val_loss: 8188.0962 - val_r2_keras: -5.3164e+01 - val_mean_squared_error: 8188.0962
# Epoch 7/500
# 4s - loss: 7788.5386 - r2_keras: -5.0104e+01 - mean_squared_error: 7788.5386 - val_loss: 7354.5693 - val_r2_keras: -4.7641e+01 - val_mean_squared_error: 7354.5693
# Epoch 8/500
# 3s - loss: 7143.1586 - r2_keras: -4.6185e+01 - mean_squared_error: 7143.1586 - val_loss: 6559.0305 - val_r2_keras: -4.2370e+01 - val_mean_squared_error: 6559.0305
# Epoch 9/500
# 3s - loss: 6452.0904 - r2_keras: -4.1115e+01 - mean_squared_error: 6452.0904 - val_loss: 6506.1884 - val_r2_keras: -4.2017e+01 - val_mean_squared_error: 6506.1884
# Epoch 10/500
# 3s - loss: 5721.1917 - r2_keras: -3.6505e+01 - mean_squared_error: 5721.1917 - val_loss: 5181.3942 - val_r2_keras: -3.3240e+01 - val_mean_squared_error: 5181.3942
# Epoch 11/500
# 3s - loss: 4963.3303 - r2_keras: -3.1239e+01 - mean_squared_error: 4963.3303 - val_loss: 4703.5507 - val_r2_keras: -3.0073e+01 - val_mean_squared_error: 4703.5507
# Epoch 12/500
# 4s - loss: 4210.1153 - r2_keras: -2.6284e+01 - mean_squared_error: 4210.1153 - val_loss: 4067.6217 - val_r2_keras: -2.5881e+01 - val_mean_squared_error: 4067.6217
# Epoch 13/500
# 4s - loss: 3471.6790 - r2_keras: -2.1764e+01 - mean_squared_error: 3471.6790 - val_loss: 3139.9561 - val_r2_keras: -1.9768e+01 - val_mean_squared_error: 3139.9561
# Epoch 14/500
# 3s - loss: 2772.8044 - r2_keras: -1.7028e+01 - mean_squared_error: 2772.8044 - val_loss: 2253.1842 - val_r2_keras: -1.3897e+01 - val_mean_squared_error: 2253.1842
# Epoch 15/500
# 3s - loss: 2123.5095 - r2_keras: -1.2994e+01 - mean_squared_error: 2123.5095 - val_loss: 1717.0353 - val_r2_keras: -1.0328e+01 - val_mean_squared_error: 1717.0353
# Epoch 16/500
# 4s - loss: 1511.6270 - r2_keras: -8.9265e+00 - mean_squared_error: 1511.6270 - val_loss: 1034.3719 - val_r2_keras: -5.8165e+00 - val_mean_squared_error: 1034.3719
# Epoch 17/500
# 4s - loss: 1010.6197 - r2_keras: -5.5359e+00 - mean_squared_error: 1010.6197 - val_loss: 701.1402 - val_r2_keras: -3.6226e+00 - val_mean_squared_error: 701.1402
# Epoch 18/500
# 3s - loss: 605.9357 - r2_keras: -3.0061e+00 - mean_squared_error: 605.9357 - val_loss: 486.9668 - val_r2_keras: -2.2001e+00 - val_mean_squared_error: 486.9668
# Epoch 19/500
# 3s - loss: 336.7340 - r2_keras: -1.1898e+00 - mean_squared_error: 336.7340 - val_loss: 186.1766 - val_r2_keras: -2.1475e-01 - val_mean_squared_error: 186.1766
# Epoch 20/500
# 3s - loss: 191.9678 - r2_keras: -2.1337e-01 - mean_squared_error: 191.9678 - val_loss: 226.0118 - val_r2_keras: -4.8339e-01 - val_mean_squared_error: 226.0118
# Epoch 21/500
# 3s - loss: 143.3974 - r2_keras: 0.1091 - mean_squared_error: 143.3974 - val_loss: 177.6188 - val_r2_keras: -1.6273e-01 - val_mean_squared_error: 177.6188
# Epoch 22/500
# 4s - loss: 134.7362 - r2_keras: 0.1750 - mean_squared_error: 134.7362 - val_loss: 101.0004 - val_r2_keras: 0.3424 - val_mean_squared_error: 101.0004
# Epoch 23/500
# 3s - loss: 127.6949 - r2_keras: 0.2038 - mean_squared_error: 127.6949 - val_loss: 95.2603 - val_r2_keras: 0.3822 - val_mean_squared_error: 95.2603
# Epoch 24/500
# 4s - loss: 132.6108 - r2_keras: 0.1763 - mean_squared_error: 132.6108 - val_loss: 152.2266 - val_r2_keras: 0.0127 - val_mean_squared_error: 152.2266
# Epoch 25/500
# 3s - loss: 135.7707 - r2_keras: 0.1517 - mean_squared_error: 135.7707 - val_loss: 178.3958 - val_r2_keras: -1.6403e-01 - val_mean_squared_error: 178.3958
# Epoch 26/500
# 4s - loss: 128.8590 - r2_keras: 0.1883 - mean_squared_error: 128.8590 - val_loss: 94.0657 - val_r2_keras: 0.3933 - val_mean_squared_error: 94.0657
# Epoch 27/500
# 3s - loss: 119.4632 - r2_keras: 0.2439 - mean_squared_error: 119.4632 - val_loss: 112.9460 - val_r2_keras: 0.2677 - val_mean_squared_error: 112.9460
# Epoch 28/500
# 4s - loss: 116.7219 - r2_keras: 0.2565 - mean_squared_error: 116.7219 - val_loss: 171.9903 - val_r2_keras: -1.1397e-01 - val_mean_squared_error: 171.9903
# Epoch 29/500
# 4s - loss: 116.6625 - r2_keras: 0.2713 - mean_squared_error: 116.6625 - val_loss: 107.6914 - val_r2_keras: 0.3063 - val_mean_squared_error: 107.6914
# Epoch 30/500
# 4s - loss: 117.5251 - r2_keras: 0.2551 - mean_squared_error: 117.5251 - val_loss: 78.5794 - val_r2_keras: 0.4938 - val_mean_squared_error: 78.5794
# Epoch 31/500
# 4s - loss: 113.6393 - r2_keras: 0.2866 - mean_squared_error: 113.6393 - val_loss: 108.7657 - val_r2_keras: 0.2960 - val_mean_squared_error: 108.7657
# Epoch 32/500
# 4s - loss: 114.2386 - r2_keras: 0.2709 - mean_squared_error: 114.2386 - val_loss: 85.5774 - val_r2_keras: 0.4510 - val_mean_squared_error: 85.5774
# Epoch 33/500
# 4s - loss: 106.5597 - r2_keras: 0.3195 - mean_squared_error: 106.5597 - val_loss: 155.2764 - val_r2_keras: -1.6203e-03 - val_mean_squared_error: 155.2764
# Epoch 34/500
# 4s - loss: 109.8146 - r2_keras: 0.3109 - mean_squared_error: 109.8146 - val_loss: 82.2408 - val_r2_keras: 0.4731 - val_mean_squared_error: 82.2408
# Epoch 35/500
# 4s - loss: 103.8397 - r2_keras: 0.3340 - mean_squared_error: 103.8397 - val_loss: 120.8534 - val_r2_keras: 0.2198 - val_mean_squared_error: 120.8534
# Epoch 36/500
# 4s - loss: 109.0944 - r2_keras: 0.3038 - mean_squared_error: 109.0944 - val_loss: 128.3392 - val_r2_keras: 0.1639 - val_mean_squared_error: 128.3392
# Epoch 37/500
# 4s - loss: 105.6066 - r2_keras: 0.3233 - mean_squared_error: 105.6066 - val_loss: 118.5866 - val_r2_keras: 0.2324 - val_mean_squared_error: 118.5866
# Epoch 38/500
# 4s - loss: 100.8898 - r2_keras: 0.3592 - mean_squared_error: 100.8898 - val_loss: 87.9579 - val_r2_keras: 0.4374 - val_mean_squared_error: 87.9579
# Epoch 39/500
# 3s - loss: 98.3211 - r2_keras: 0.3699 - mean_squared_error: 98.3211 - val_loss: 107.1641 - val_r2_keras: 0.3048 - val_mean_squared_error: 107.1641
# Epoch 40/500
# 3s - loss: 99.9855 - r2_keras: 0.3544 - mean_squared_error: 99.9855 - val_loss: 95.7634 - val_r2_keras: 0.3756 - val_mean_squared_error: 95.7634
# Epoch 41/500
# 3s - loss: 94.9374 - r2_keras: 0.3972 - mean_squared_error: 94.9374 - val_loss: 102.3124 - val_r2_keras: 0.3405 - val_mean_squared_error: 102.3124
# Epoch 42/500
# 4s - loss: 95.0815 - r2_keras: 0.3953 - mean_squared_error: 95.0815 - val_loss: 113.6543 - val_r2_keras: 0.2728 - val_mean_squared_error: 113.6543
# Epoch 43/500
# 3s - loss: 95.2793 - r2_keras: 0.3562 - mean_squared_error: 95.2793 - val_loss: 82.6577 - val_r2_keras: 0.4736 - val_mean_squared_error: 82.6577
# Epoch 44/500
# 3s - loss: 93.1857 - r2_keras: 0.3970 - mean_squared_error: 93.1857 - val_loss: 101.6776 - val_r2_keras: 0.3462 - val_mean_squared_error: 101.6776
# Epoch 45/500
# 3s - loss: 89.7959 - r2_keras: 0.4216 - mean_squared_error: 89.7959 - val_loss: 77.4058 - val_r2_keras: 0.5035 - val_mean_squared_error: 77.4058
# Epoch 46/500
# 3s - loss: 91.8311 - r2_keras: 0.4128 - mean_squared_error: 91.8311 - val_loss: 97.8937 - val_r2_keras: 0.3733 - val_mean_squared_error: 97.8937
# Epoch 47/500
# 4s - loss: 87.8219 - r2_keras: 0.4407 - mean_squared_error: 87.8219 - val_loss: 147.1757 - val_r2_keras: 0.0472 - val_mean_squared_error: 147.1757
# Epoch 48/500
# 3s - loss: 88.3848 - r2_keras: 0.4315 - mean_squared_error: 88.3848 - val_loss: 84.3869 - val_r2_keras: 0.4590 - val_mean_squared_error: 84.3869
# Epoch 49/500
# 3s - loss: 90.4416 - r2_keras: 0.4171 - mean_squared_error: 90.4416 - val_loss: 87.5934 - val_r2_keras: 0.4382 - val_mean_squared_error: 87.5934
# Epoch 50/500
# 3s - loss: 86.9286 - r2_keras: 0.4396 - mean_squared_error: 86.9286 - val_loss: 82.4832 - val_r2_keras: 0.4709 - val_mean_squared_error: 82.4832
# Epoch 51/500
# 3s - loss: 85.2981 - r2_keras: 0.4588 - mean_squared_error: 85.2981 - val_loss: 96.4122 - val_r2_keras: 0.3867 - val_mean_squared_error: 96.4122
# Epoch 52/500
# 3s - loss: 81.5368 - r2_keras: 0.4805 - mean_squared_error: 81.5368 - val_loss: 111.3363 - val_r2_keras: 0.2835 - val_mean_squared_error: 111.3363
# Epoch 53/500
# 3s - loss: 85.2462 - r2_keras: 0.4545 - mean_squared_error: 85.2462 - val_loss: 86.6031 - val_r2_keras: 0.4422 - val_mean_squared_error: 86.6031
# Epoch 54/500
# 3s - loss: 84.9236 - r2_keras: 0.4540 - mean_squared_error: 84.9236 - val_loss: 84.1975 - val_r2_keras: 0.4605 - val_mean_squared_error: 84.1975
# Epoch 55/500
# 3s - loss: 77.9474 - r2_keras: 0.5028 - mean_squared_error: 77.9474 - val_loss: 96.1077 - val_r2_keras: 0.3883 - val_mean_squared_error: 96.1077
# Epoch 56/500
# 3s - loss: 85.1467 - r2_keras: 0.4511 - mean_squared_error: 85.1467 - val_loss: 86.7991 - val_r2_keras: 0.4469 - val_mean_squared_error: 86.7991
# Epoch 57/500
# 3s - loss: 76.9334 - r2_keras: 0.5075 - mean_squared_error: 76.9334 - val_loss: 92.3922 - val_r2_keras: 0.4081 - val_mean_squared_error: 92.3922
# Epoch 58/500
# 3s - loss: 80.0246 - r2_keras: 0.4882 - mean_squared_error: 80.0246 - val_loss: 93.4116 - val_r2_keras: 0.4039 - val_mean_squared_error: 93.4116
# Epoch 59/500
# 3s - loss: 78.7879 - r2_keras: 0.4910 - mean_squared_error: 78.7879 - val_loss: 88.6517 - val_r2_keras: 0.4333 - val_mean_squared_error: 88.6517
# Epoch 60/500
# 3s - loss: 75.0066 - r2_keras: 0.5191 - mean_squared_error: 75.0066 - val_loss: 94.4749 - val_r2_keras: 0.3965 - val_mean_squared_error: 94.4749
# Epoch 61/500
# 4s - loss: 73.0338 - r2_keras: 0.5336 - mean_squared_error: 73.0338 - val_loss: 81.7321 - val_r2_keras: 0.4789 - val_mean_squared_error: 81.7321
# Epoch 62/500
# 4s - loss: 77.6672 - r2_keras: 0.5057 - mean_squared_error: 77.6672 - val_loss: 83.4782 - val_r2_keras: 0.4663 - val_mean_squared_error: 83.4782
# Epoch 63/500
# 4s - loss: 73.6814 - r2_keras: 0.5225 - mean_squared_error: 73.6814 - val_loss: 91.8369 - val_r2_keras: 0.4151 - val_mean_squared_error: 91.8369
# Epoch 64/500
# 4s - loss: 71.2394 - r2_keras: 0.5376 - mean_squared_error: 71.2394 - val_loss: 101.5051 - val_r2_keras: 0.3465 - val_mean_squared_error: 101.5051
# Epoch 65/500
# 3s - loss: 76.5840 - r2_keras: 0.4891 - mean_squared_error: 76.5840 - val_loss: 84.6469 - val_r2_keras: 0.4578 - val_mean_squared_error: 84.6469
# Epoch 66/500
# 3s - loss: 71.3170 - r2_keras: 0.5453 - mean_squared_error: 71.3170 - val_loss: 90.3358 - val_r2_keras: 0.4210 - val_mean_squared_error: 90.3358
# Epoch 00065: early stopping
# dict_keys(['val_loss', 'r2_keras', 'val_r2_keras', 'loss', 'mean_squared_error', 'val_mean_squared_error'])
# MSE train: 6.840015568501235
# R^2 train: 0.7111936531846033
# MSE val: 8.79805526065887
# R^2 val: 0.5026931809519739

# %%
# predict results
res = estimator.predict(X_test).ravel()
print(res)

# create df and convert it to csv
output = pd.DataFrame({'id': id_test, 'y': res})
output.to_csv('keras-baseline.csv', index=False)
# Out:
# [  68.58505249   92.76982117   70.00527191 ...,   89.03775024  112.55752563
#    92.19618225]
